# %%
a=5
b=10
sum=a**2+b**2
print(sum)
# Out:
# 125

# %%
# x1=3
y1=3
x2=6
y2=7
d=(x2-x1)**2+(y2-y1)**2
ds=d**0.5
print(ds)

# %% [markdown]
# import matplotlib.pyplot as plt
# plt.plot([3,6],[3,7])
# plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot([3,6],[3,7],color="green") 
plt.plot([4,6],[5,7],color="orange") 
plt.show()

# %%
old=20
price=19.9
name="han"
is_online=True
print(type(old))
print(type(price))
print(type(name))
print(type(is_online))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name=input("你的名字?")
print("Hello,"+name)
# Out:
# 你的名字?23
# Hello,23

# %% [markdown]
# ### HI

# %%
x=[None]*3
x[0]=1
x[1]=2
x[2]=3
print(x)

x=[]
for i in range(7):
    x.append(i+1)
y=[1.5,2,3,4,2,3,5]
print(x)
print(y)
print(len(x))
print(len(y))

import matplotlib.pyplot as plt
plt.plot(x,y)
plt.xlabel('Month')
plt.ylabel('NT*10K')
plt.show()

import random



r=[]
for i in range(7):
    m=random.randint(15000,50000)
    print(m)
    r.append(m/10000)
print(r)

plt.plot(x,y,x,r)
plt.xlabel('Month')
plt.ylabel('NT*10K*')
plt.show()

z=['t','f','b','e']
s=[3000,8000,2000,3500]

div=(0.1,0,0,0)
exp=(0,0,0,0.4)
plt.pie(s,labels=z,explode=exp)
plt.show()
# Out:
# [1, 2, 3]
# [1, 2, 3, 4, 5, 6, 7]
# [1.5, 2, 3, 4, 2, 3, 5]
# 7
# 7
# 38081
# 35878
# 43815
# 31751
# 17010
# 35341
# 16188
# [3.8081, 3.5878, 4.3815, 3.1751, 1.701, 3.5341, 1.6188]

# %%
[None]*3
# Out:
# [None, None, None]

# %%
1
