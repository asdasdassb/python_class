# %%
def priority(op):
    return 1 if op in "+-" else 2 if op in "/" else 0


def toPostfix(infix, isPost=True):
    toStack, toOutput = ('(', ')') if isPost else (')', '(')

    def procOpt(c, stack, output):
        if stack == "" or priority(stack[-1]) < priority(c):
            return ( stack + c, output)
        else:
            return procOpt(c, stack[0:-1], output + stack[-1])

    def procPhs(stack, output):
        if stack[-1] == toStack:
            return (stack[0:-1], output)
        else:
            return procPhs(stack[0:-1], output + stack[-1])

    def procExpr(expr, stack="", output=""):
        if expr == "":
            return output + stack[::-1]
        elif expr[0] == toStack:
            return procExpr(expr[1:], stack + expr[0], output)
        elif expr[0] in "+-/":
            return procExpr(expr[1:], procOpt(expr[0], stack, output))
        elif expr[0] == toOutput:
            return procExpr(expr[1:], procPhs(stack, output))
        else:
            return procExpr(expr[1:], stack, output + expr[0])

    output = procExpr(infix if isPost else infix[::-1])
    return output if isPost else output[::-1]


def toPrefix(infix):
    return toPostfix(infix, False)


infix = "A+BC/D-(E+F)G-H"

print("後序"+toPostfix(infix))
print("前序"+toPrefix(infix))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in <module>
#      40 infix = "A+BC/D-(E+F)G-H"
#      41
# ---> 42 print("後序"+toPostfix(infix))
#      43 print("前序"+toPrefix(infix))
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in toPostfix(infix, isPost)
#      30             return procExpr(expr[1:], stack, output + expr[0])
#      31
# ---> 32     output = procExpr(infix if isPost else infix[::-1])
#      33     return output if isPost else output[::-1]
#      34
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in procExpr(expr, stack, output)
#      28             return procExpr(expr[1:], procPhs(stack, output))
#      29         else:
# ---> 30             return procExpr(expr[1:], stack, output + expr[0])
#      31
#      32     output = procExpr(infix if isPost else infix[::-1])
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in procExpr(expr, stack, output)
#      24             return procExpr(expr[1:], stack + expr[0], output)
#      25         elif expr[0] in "+-/":
# ---> 26             return procExpr(expr[1:], procOpt(expr[0], stack, output))
#      27         elif expr[0] == toOutput:
#      28             return procExpr(expr[1:], procPhs(stack, output))
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in procExpr(expr, stack, output)
#      28             return procExpr(expr[1:], procPhs(stack, output))
#      29         else:
# ---> 30             return procExpr(expr[1:], stack, output + expr[0])
#      31
#      32     output = procExpr(infix if isPost else infix[::-1])
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in procExpr(expr, stack, output)
#      28             return procExpr(expr[1:], procPhs(stack, output))
#      29         else:
# ---> 30             return procExpr(expr[1:], stack, output + expr[0])
#      31
#      32     output = procExpr(infix if isPost else infix[::-1])
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in procExpr(expr, stack, output)
#      24             return procExpr(expr[1:], stack + expr[0], output)
#      25         elif expr[0] in "+-/":
# ---> 26             return procExpr(expr[1:], procOpt(expr[0], stack, output))
#      27         elif expr[0] == toOutput:
#      28             return procExpr(expr[1:], procPhs(stack, output))
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in procExpr(expr, stack, output)
#      28             return procExpr(expr[1:], procPhs(stack, output))
#      29         else:
# ---> 30             return procExpr(expr[1:], stack, output + expr[0])
#      31
#      32     output = procExpr(infix if isPost else infix[::-1])
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in procExpr(expr, stack, output)
#      24             return procExpr(expr[1:], stack + expr[0], output)
#      25         elif expr[0] in "+-/":
# ---> 26             return procExpr(expr[1:], procOpt(expr[0], stack, output))
#      27         elif expr[0] == toOutput:
#      28             return procExpr(expr[1:], procPhs(stack, output))
#
# ~\AppData\Local\Temp\ipykernel_28240\1754631009.py in procExpr(expr, stack, output)
#      22             return output + stack[::-1]
#      23         elif expr[0] == toStack:
# ---> 24             return procExpr(expr[1:], stack + expr[0], output)
#      25         elif expr[0] in "+-/":
#      26             return procExpr(expr[1:], procOpt(expr[0], stack, output))
#
# TypeError: can only concatenate tuple (not "str") to tuple
