# %%
import requests
r=requests.get('https://www.google.com.tw')
print("this answer is: ", r.status_code)
print(r.text)
# Out:
# this answer is:  200
# ...

# %%
import requests
post_data={'name':'b0909014','password':'123'}
url='http://www.google.com.tw'
url1='http://www.httpbin.org'
url2='http://www.httpbin.org/post'
r1=requests.post(url2,data=post_data)
r.encoding="utf-8"
#print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "name": "b0909014",
#     "password": "123"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "26",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "www.httpbin.org",
#     "User-Agent": "python-requests/2.24.0",
#     "X-Amzn-Trace-Id": "Root=1-628700a4-21281b483c658ac60510f845"
#   },
#   "json": null,
#   "origin": "111.255.248.76",
#   "url": "http://www.httpbin.org/post"
# }

# %%
import requests
r2=requests.get('https://www.google.com.tw')
r3=requests.get("https://www.cnu.edu.tw/")
r3.encoding="utf-8"
from bs4 import BeautifulSoup
soup=BeautifulSoup(r3.text,"lxml")

print(soup)
# Out:
# <!DOCTYPE html>
# <!-- Filtering SQL injection --><html lang="zh-tw">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="嘉南藥理大學, 嘉藥, 嘉藥學校財團法人嘉南藥理大學, China Nan University Pharmacy ＆ Science, CNU" name="keywords"/>
# <meta content="嘉南藥理大學(Chia Nan University of Pharmacy ＆ Science)，簡稱嘉藥，於民國53年由創辦人結合醫藥界與教育界所籌創。嘉藥的校訓為「真實」二字，為培育從事醫藥、衛生、保健、環境、休閒及管理等專業人才。" name="description"/>
# <meta content="本網站通過A檢測等級無障礙網頁檢測" name="Accessible_website"/>
# <link href="favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!-- Apple Touch Icons -->
# <link href="apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# ...

# %%
with open('C:/123/b0909014.html','r',encoding='utf-8') as fp:
    soup1=BeautifulSoup(fp,'lxml')
print(soup1.prettify())
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <p>
#    B0909014_曾薪翰
#   </p>
#   <h1>
#    這是測試 HAN 123
#   </h1>
#   以自傳《五體不滿足》聲名大噪的的日本作家乙武洋匡，近年來深受婚外情困擾，形象盪入谷底。不過，他在19日突然透過影片宣布，將以無黨籍身分投入東京都參議員選舉。
#
# 現年46歲的乙武洋匡出生於日本東京都新宿區，因罹患先天性四肢切斷症，出生時就缺少四肢，但他以自傳「五體不滿足」聲名大噪、成為日本知名勵志作家。
#
# 不過，乙武洋匡在2016年被爆出和20多歲女性有婚外情，劈腿女性多達50人，同年與大學學妹妻子離婚收場。形象盪入谷底，許多代言和演講紛紛遭到取消。
#
# 乙武洋匡近年來力圖擺脫放蕩形象，在2019年2月在Instagram發布穿著義肢練習走路的影片，當時他參與義肢開發工作《乙武計畫》（OTOTAKE PROJECT），投入高科技輔具訓練，並在今年PO出肉身爬樓梯照片、一口氣就爬了60層樓，並透露去年完成了11500層樓的爬梯訓練。
#
# 乙武洋匡19日晚間在他的YouTube頻道「乙武洋匡の情熱教室 - Limitless OTO」以及個人網站上以「報告我的決心」為題宣布，他決定以獨立參選人的身分，參選今年夏天的參議院東京選區。
#
# 乙武洋匡表示，日本有許多放棄的人以及覺得生活現狀無法改變的人，他想為這些人創造更多選擇機會，這就是他投入政治的原因，並重申自己永不放棄的信念。
#
# 乙武洋匡在2016年本來有意以自民黨籍競選參議員，但因婚外情醜聞放棄參選
#   <br/>
#   <br/>
#   <br/>
#   <img height="300" src="C:\Users\asdas\Desktop\資料夾\垃圾\IMG_0465.png" width="300"/>
#  </body>
# </html>
